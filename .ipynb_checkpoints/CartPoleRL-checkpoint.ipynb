# %%
import gym
from stable_baselines3 import PPO

# make environment
env = gym.make('CartPole-v1')
obs = env.reset()
for i in range(500):
    #action, _states = model.predict(obs)
    action = env.action_space.sample()
    obs, rewards, dones, info = env.step(action)
    env.render()

env.close()

# %%
#training
model = PPO('MlpPolicy', env, verbose=1)
model.learn(total_timesteps=25000)
# Out:
# Using cpu device
# Wrapping the env with a `Monitor` wrapper
# Wrapping the env in a DummyVecEnv.
# ---------------------------------
# | rollout/           |          |
# |    ep_len_mean     | 24.6     |
# |    ep_rew_mean     | 24.6     |
# | time/              |          |
# |    fps             | 729      |
# |    iterations      | 1        |
# |    time_elapsed    | 2        |
# |    total_timesteps | 2048     |
# ---------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 28.9        |
# |    ep_rew_mean          | 28.9        |
# | time/                   |             |
# |    fps                  | 504         |
# |    iterations           | 2           |
# |    time_elapsed         | 8           |
# |    total_timesteps      | 4096        |
# | train/                  |             |
# |    approx_kl            | 0.009423597 |
# |    clip_fraction        | 0.109       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.686      |
# |    explained_variance   | 0.00143     |
# |    learning_rate        | 0.0003      |
# |    loss                 | 6.42        |
# |    n_updates            | 10          |
# |    policy_gradient_loss | -0.0195     |
# |    value_loss           | 60.5        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 34          |
# |    ep_rew_mean          | 34          |
# | time/                   |             |
# |    fps                  | 447         |
# |    iterations           | 3           |
# |    time_elapsed         | 13          |
# |    total_timesteps      | 6144        |
# | train/                  |             |
# |    approx_kl            | 0.010294156 |
# |    clip_fraction        | 0.0584      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.669      |
# |    explained_variance   | 0.0466      |
# |    learning_rate        | 0.0003      |
# |    loss                 | 14.2        |
# |    n_updates            | 20          |
# |    policy_gradient_loss | -0.0156     |
# |    value_loss           | 38.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 41.4        |
# |    ep_rew_mean          | 41.4        |
# | time/                   |             |
# |    fps                  | 421         |
# |    iterations           | 4           |
# |    time_elapsed         | 19          |
# |    total_timesteps      | 8192        |
# | train/                  |             |
# |    approx_kl            | 0.009079549 |
# |    clip_fraction        | 0.111       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.632      |
# |    explained_variance   | 0.207       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 19.9        |
# |    n_updates            | 30          |
# |    policy_gradient_loss | -0.0203     |
# |    value_loss           | 52.6        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 55.9        |
# |    ep_rew_mean          | 55.9        |
# | time/                   |             |
# |    fps                  | 401         |
# |    iterations           | 5           |
# |    time_elapsed         | 25          |
# |    total_timesteps      | 10240       |
# | train/                  |             |
# |    approx_kl            | 0.013391657 |
# |    clip_fraction        | 0.143       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.596      |
# |    explained_variance   | 0.338       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 31.1        |
# |    n_updates            | 40          |
# |    policy_gradient_loss | -0.0259     |
# |    value_loss           | 60.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 70.9        |
# |    ep_rew_mean          | 70.9        |
# | time/                   |             |
# |    fps                  | 397         |
# |    iterations           | 6           |
# |    time_elapsed         | 30          |
# |    total_timesteps      | 12288       |
# | train/                  |             |
# |    approx_kl            | 0.009250335 |
# |    clip_fraction        | 0.0582      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.587      |
# |    explained_variance   | 0.366       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 25          |
# |    n_updates            | 50          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 58.4        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 86.3        |
# |    ep_rew_mean          | 86.3        |
# | time/                   |             |
# |    fps                  | 394         |
# |    iterations           | 7           |
# |    time_elapsed         | 36          |
# |    total_timesteps      | 14336       |
# | train/                  |             |
# |    approx_kl            | 0.007537894 |
# |    clip_fraction        | 0.0789      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.597       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 18.1        |
# |    n_updates            | 60          |
# |    policy_gradient_loss | -0.0136     |
# |    value_loss           | 51.2        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 104         |
# |    ep_rew_mean          | 104         |
# | time/                   |             |
# |    fps                  | 393         |
# |    iterations           | 8           |
# |    time_elapsed         | 41          |
# |    total_timesteps      | 16384       |
# | train/                  |             |
# |    approx_kl            | 0.007339298 |
# |    clip_fraction        | 0.106       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.813       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 36.5        |
# |    n_updates            | 70          |
# |    policy_gradient_loss | -0.0131     |
# |    value_loss           | 38.4        |
# -----------------------------------------
# ------------------------------------------
# | rollout/                |              |
# |    ep_len_mean          | 122          |
# |    ep_rew_mean          | 122          |
# | time/                   |              |
# |    fps                  | 392          |
# |    iterations           | 9            |
# |    time_elapsed         | 47           |
# |    total_timesteps      | 18432        |
# | train/                  |              |
# |    approx_kl            | 0.0100155845 |
# |    clip_fraction        | 0.0863       |
# |    clip_range           | 0.2          |
# |    entropy_loss         | -0.558       |
# |    explained_variance   | 0.697        |
# |    learning_rate        | 0.0003       |
# |    loss                 | 4.69         |
# |    n_updates            | 80           |
# |    policy_gradient_loss | -0.00778     |
# |    value_loss           | 42.7         |
# ------------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 139         |
# |    ep_rew_mean          | 139         |
# | time/                   |             |
# |    fps                  | 391         |
# |    iterations           | 10          |
# |    time_elapsed         | 52          |
# |    total_timesteps      | 20480       |
# | train/                  |             |
# |    approx_kl            | 0.006393537 |
# |    clip_fraction        | 0.0659      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.576      |
# |    explained_variance   | 0.895       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 11.4        |
# |    n_updates            | 90          |
# |    policy_gradient_loss | -0.00705    |
# |    value_loss           | 23          |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 158         |
# |    ep_rew_mean          | 158         |
# | time/                   |             |
# |    fps                  | 390         |
# |    iterations           | 11          |
# |    time_elapsed         | 57          |
# |    total_timesteps      | 22528       |
# | train/                  |             |
# |    approx_kl            | 0.006874851 |
# |    clip_fraction        | 0.079       |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.58       |
# |    explained_variance   | 0.922       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 2.43        |
# |    n_updates            | 100         |
# |    policy_gradient_loss | -0.0127     |
# |    value_loss           | 15.7        |
# -----------------------------------------
# -----------------------------------------
# | rollout/                |             |
# |    ep_len_mean          | 177         |
# |    ep_rew_mean          | 177         |
# | time/                   |             |
# |    fps                  | 389         |
# |    iterations           | 12          |
# |    time_elapsed         | 63          |
# |    total_timesteps      | 24576       |
# | train/                  |             |
# |    approx_kl            | 0.003519188 |
# |    clip_fraction        | 0.0127      |
# |    clip_range           | 0.2         |
# |    entropy_loss         | -0.551      |
# |    explained_variance   | 0.203       |
# |    learning_rate        | 0.0003      |
# |    loss                 | 7.22        |
# |    n_updates            | 110         |
# |    policy_gradient_loss | -0.00361    |
# |    value_loss           | 54.4        |
# -----------------------------------------
# ----------------------------------------
# | rollout/                |            |
# |    ep_len_mean          | 195        |
# |    ep_rew_mean          | 195        |
# | time/                   |            |
# |    fps                  | 389        |
# |    iterations           | 13         |
# |    time_elapsed         | 68         |
# |    total_timesteps      | 26624      |
# | train/                  |            |
# |    approx_kl            | 0.00152003 |
# |    clip_fraction        | 0.00664    |
# |    clip_range           | 0.2        |
# |    entropy_loss         | -0.542     |
# |    explained_variance   | 0.385      |
# |    learning_rate        | 0.0003     |
# |    loss                 | 3.85       |
# |    n_updates            | 120        |
# |    policy_gradient_loss | -0.00157   |
# |    value_loss           | 31.9       |
# ----------------------------------------

# %%
# test on environment
obs = env.reset()
for i in range(1000):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    env.render()
env.close()
